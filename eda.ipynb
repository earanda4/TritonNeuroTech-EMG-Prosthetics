# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df01_1 = pd.read_csv('EMG_data_for_gestures-master/01/1_raw_data_13-12_22.03.16.txt', sep='\t')
df01_1
# Out:
#         time  channel1  channel2  channel3  channel4  channel5  channel6  \
# 0          1   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001
# 1          5   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001
# 2          6  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002
# 3          7  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002
# 4          8  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002
# ...      ...       ...       ...       ...       ...       ...       ...
# 63191  65657  -0.00001   0.00001  -0.00005  -0.00001  -0.00003  -0.00001
# 63192  65658  -0.00001   0.00001  -0.00005  -0.00001  -0.00003  -0.00001
# 63193  65659  -0.00001   0.00001  -0.00005  -0.00001  -0.00003  -0.00001
# 63194  65660  -0.00001   0.00001  -0.00005  -0.00001  -0.00003  -0.00001
# 63195  65661  -0.00001   0.00001  -0.00005  -0.00001  -0.00003  -0.00001
#
#        channel7  channel8  class
# 0       0.00000  -0.00001      0
# ...

# %%
# checking if all times are unique
np.unique(df01_1['time']).shape[0] == df01_1.shape[0]
# Out:
# True

# %%
df01_1.shape
# Out:
# (63196, 10)

# %%
df01_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63196 entries, 0 to 63195
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      63196 non-null  int64
#  1   channel1  63196 non-null  float64
#  2   channel2  63196 non-null  float64
#  3   channel3  63196 non-null  float64
#  4   channel4  63196 non-null  float64
#  5   channel5  63196 non-null  float64
#  6   channel6  63196 non-null  float64
#  7   channel7  63196 non-null  float64
#  8   channel8  63196 non-null  float64
#  9   class     63196 non-null  int64
# dtypes: float64(8), int64(2)
# memory usage: 4.8 MB

# %%
df01_1.describe()
# Out:
#                time      channel1      channel2      channel3      channel4  \
# count  63196.000000  63196.000000  63196.000000  63196.000000  63196.000000
# mean   32777.490094     -0.000008     -0.000009     -0.000009     -0.000010
# std    18943.835626      0.000144      0.000134      0.000124      0.000155
# min        1.000000     -0.001110     -0.001020     -0.000910     -0.001040
# 25%    16340.750000     -0.000030     -0.000040     -0.000050     -0.000040
# 50%    32781.500000     -0.000010     -0.000010     -0.000010     -0.000010
# 75%    49199.250000      0.000010      0.000020      0.000030      0.000020
# max    65661.000000      0.001270      0.001270      0.001270      0.001270
#
#            channel5     channel6      channel7      channel8         class
# count  63196.000000  63196.00000  63196.000000  63196.000000  63196.000000
# mean      -0.000012     -0.00001     -0.000008     -0.000008      1.212086
# ...

# %%
df01_1['class'].value_counts()
# Out:
# class
# 0    41272
# 3     3816
# 1     3780
# 6     3747
# 5     3615
# 2     3525
# 4     3441
# Name: count, dtype: int64

# %%
for k in range(1, 6):
    for i in range(1, 9):
        plt.figure(i)
        plt.hist(df01_1[df01_1['class'] == k][f'channel{i}'], alpha=0.4)

# %%
# look into sliding window for training RNN 
# long-short term memory with sliding window
